# %% [markdown]
# # Assignment 03: Data Classification using the Keras Functional API
# ---
#
# **Due Date:** Wednesday 06/10/2026 (by midnight)

# %% [markdown]
# **Please fill these in before submitting, just in case I accidentally mix up file names while grading**:
#
# Name: Jane Hacker
#
# CWID-5: (Last 5 digits of cwid)

# %% [markdown]
# # Introduction
#
# Welcome to our third assignment for the class.  Its time to build your first neural network using the Keras API.  You will be using a dataset to perform classification that only has 2 features,
# but that is not linearly separable.  You will start with a simple single layer, which is equivalent to a simple logistic regressor, then you will increase the power of the model to try and
# see how that effects the decision boundary that a model with more representational power can make.
#
# **Instructions:**
#
# - Do not use loops (for/while) in your code, unless the instructions explicitly ask you to do so.
# - Use the Keras functional API to implement your asked for network architectures, and to practice and
#   get used to specifying models using that API.
#
# **You will learn:**
#
# - How to implement a 2-class classification neural network with a single hidden layer
# - How representational power effects the types of decision boundary a model can form for a classification problem.

# %% [markdown]
# # Packages
#
# The following imports should be all of the packages that you will need for this assignment
# (notice we are not yet using Keras/Tensorflow).  We will start using the Keras API in this
# assignment, so the `tensorflow` and `keras` modules you need are now available in the notebook.

# %%
# assignment wide imports go here, usually all of your imports for notebooks should
# be put up at the top here, if they were not given to you at the start of the assignment
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from mlxtend.plotting import plot_decision_regions

# %%
# The following ipython magic will reload changed file/modules.
# So when editing function in source code modules, you should
# be able to just rerun the cell, not restart the whole kernel.
# %load_ext autoreload
# %autoreload 2

# %%
# assignment function imports for doctests and github autograding
# these are required for assignment autograding
# NOTE: The following requires that the PYTHONPATH is correctly set in the jupyter lab environment
from assg_utils import run_unittests, run_doctests
from assg_tasks import get_logistic_regression_model
from assg_tasks import get_neural_network_model
from assg_tasks import get_more_powerful_model
from assg_tasks import load_flower_dataset
from assg_tasks import plot_history

# %% [markdown]
# # Overview of the Dataset
#
# **Problem Statement**: First let's get the dataset you will work on for this assignment.  The following
# code from `src/assg_tasks.py` will load a "flower" 2-class (binary classification) dataset into
# variables `X` and `Y`.

# %%
# Loading the flower dataset
X, Y = load_flower_dataset()

# %% [markdown]
# **Task**: In the next cell, visualize the dataset using Matplotlib. The data looks like a "flower" with some red (label y=0) and some blue (y=1) points. Your goal is to build a model to fit this data. In other words, we want the classifier to define regions as either red or blue.

# %%
# visualize the flower dataset here, make it look like the example figure

# %% [markdown]
# You should find that the `X` inputs have a shape of `(400,2)`, that is to say that
# `m` the number of samples is 400, and each sample has 2 features.  The data, if
# you create the visualization correctly, is clearly not linearly separable.
# The vector `Y` is shaped `(400,)` and contains the labels, use red class: 0 and
# blue class: 1 in your category labels.  You should attempt to make your
# figure look like the following example:
#
# ![Flower Dataset](../figures/flower_dataset.png)

# %% [markdown]
# # Task 1: Simple Logistic Regression
#
# Before building a full neural network, lets first see how logistic regression performs on this problem.
# For practice, you will use Keras.  A single layer that has 1 output unit using the `sigmoid()`
# activation function is equivalent to a logistic regression.  Use the suggested loss and activation
# functions discussed in the Chapter 04 examples that are appropriate for a binary classifier.
#
# **Task** Write a function that creates a `keras.Model` called `get_logistic_regression_model()`.
# The function should create a model with a single output layer and compile it (don't do any
# fitting or testing with it yet).  You are required to use the Keras Functional API to define
# the model architecture.
#
# You should give the name "logistic_regression_model" to your model, and name your
# layers "lr_input" and "lr_output" respectively.
#
# You should use the appropriate output activation, optimization and loss
# functions for a binary classification task in the model you create and compile.  Also make sure
# you specify that the "accuracy" metric should be monitored when you compile the model.

# %%
### TESTED FUNCTION get_logistic_regression_model()
run_unittests(['test_get_logistic_regression_model'])

lr_model = get_logistic_regression_model()

# %% [markdown]
# **Task**: In the following cell, show the summary of your logistic regression model.
# If built correctly, you should find that your model has 3 trainable parameters, which
# represents two weights for each of the two input dimensions, and a bias parameter.
#
# **Expected Result**: You should find that the logistic regression has only 3 trainable
# parameters, 2 weights for each of the two input dimensions, and a bias parameter.  You
# should find that your model and layers are named as asked for in the model architecture.

# %%
# show a summary of your logistic regression model in this cell

# %% [markdown]
# **Task**: In the next cell, use the `plot_model()` function from Keras to
# visualize your simple model architecture.  Your model should look like the following
# image.  Notice that in the figure we have given names to the model and the input and output
# layers.
#
# ![Logistic Model Architecture](../figures/lr_model.png)

# %%
# plot a visualization of your model architecture here

# %% [markdown]
# **Task**: Next train your model using the `fit()` function on the `X` inputs
# and `Y` labels.  We only have 400 samples in this data, but use the parameter to
# the `fit()` function to ask it to randomly chose 20% of the training data for
# validation.  Use a batch size of 32 for this data. Train on your logistic
# regression model for at least 500 epochs. Keep the returned history of the model fit
# so that we can plot the learning curve results next.
#
# **Expected Result**:
#
# You should find that training and validation loss will improve for the first 100-200
# epochs, and be at about the same level throughout all epochs of training.  Usually
# loss will stop improving above a 0.6 loss.
#
# The model may sometimes get up to 60% accuracy on the training data or validation data
# (the plot may be noisy in places), but both will settle at a rate of around 50% accuracy
# or worse, which is worse than simply always guessing 1 on this balanced binary dataset.

# %%
# train your logistic regression model here

# %% [markdown]
# **Task**: The `plot_history()` function that we have used in our class lecture notebooks has been copied
# to your `src/assg_tasks.py` file and imported.  Use the function to plot the training/validation
# loss and the training/validation accuracy as demonstrated in our class lectures.
#
# **Expected Result:** You should discover evidence from the plot that the simple logistic regression does not have enough
# representational power for this task.  As described before, training and validation loss will go down steadily
# for the first 100-200 epochs (indicating gradient descent is working), but will eventually stop improving
# somewhere around a loss of 0.6.  Training and validation accuracy will converge at about the same epoch
# where training loss stops improving somewhere around 50% accuracy or less.

# %%
# plot the learning curves history of the fit of your logistic regression model here

# %% [markdown]
# **Task**: Visualize the decision boundary made by your simple logistic regression classification
# model.  There is a method called `plot_decision_regions()` from the `mlxtend.plotting` library
# that has been imported.  You can see [mlxtend Examples and Documentation here](https://rasbt.github.io/mlxtend/)
# Use this function to visualize the decision boundary that is learned by your simple logistic
# regression classifier.
#
# **Expected Results**: You will see that logistic regression is a linear classifier, the classifier
# can only learn a line (in 2-D) as the decision boundary between our 0 and 1 classes.  Because this
# data is not linearly separable, a simple linear logistic regression model does not
# have enough representational power to ever learn a decision boundary that can do better than
# 50% accuracy on this data.

# %%
# plot the decision boundary your model found here

# %% [markdown]
# # Task 2: Neural Network Model
#
# A single layer logistic regression model did not work well on the flower dataset.  But a neural
# network with a single layer, and enough units in the layer, should be able to perform much better.
#
#
# **Task**:  Write a function that creates a `keras.Model` called `get_neural_network_model()`.
# The function will be similar as in Task 1, but this time create an intermediate layer
# with 64 units in it between the inputs and output. Don't forget to use the standard
# nonlinear activation function for output from this hidden layer.
# This is still a binary classification task so the optimizer, metrics and loss function
# should all be the same as in the previous task.  Name your model and layers again,
# use "neural_network_model" for the model name, and "nn_input", "nn_hidden" and "nn_output"
# for the input, hidden and output layers respectively.

# %%
### TESTED FUNCTION get_neural_network_model()
run_unittests(['test_get_neural_network_model'])

nn_model = get_neural_network_model()

# %% [markdown]
# **Task**: In the following cell, show the summary of your logistic regression model as before.
#
# **Expected Result**: You should find that your network architecture has 3 layers, and that
# the total trainable parameters is 257.  The hidden layer should have 192 parameters, do you
# know why there are 192 parameters in the intermediate layer of 64 units?  The layers should
# have been given the asked for names in this model.

# %%
# show a summary of your neural network model in this cell

# %% [markdown]
# **Task**: In the next cell, use the `plot_model()` function from Keras to
# visualize your neural network architecture again.  It should have the
# expected input, hidden and output layers in the model.

# %%
# plot a visualization of your neural network model architecture here

# %% [markdown]
# **Task**: Next train your model using the `fit()` function on the `X` inputs
# and `Y` labels.  Use the same settings as before for this training
# (500+ epochs, batch size 32, 20% of the data reserved for validation.
#
# **Expected Result**:
#
# You should find that the loss will usually keep decreasing for both training loss and validation loss.
# However notice difference from the previous model.  The level that the loss reaches should be
# much lower than before.  Also at some point training and validation loss will diverge.
#
# Looking at accuracy, usually training and validation accuracy will reach similar levels of
# around 90%.
#
# Recall the discussion from our text, in section 5.3 on improving model fit.  We have evidence that
# gradient descent is working here and it can achieve some level of generalization.  Accuracy of
# 90% shows that it is doing better than a random baseline guesser.
#
# But usually validation loss will reach a point where it stalls or keeps going down but very
# slowly.  The model appears to still be underfitting.  We should be able to get a model
# that fits better and increases accuracy above 90% here.

# %%
# fit your neural network model here

# %% [markdown]
# **Task**: Plot the loss and accuracy learning curves again for the neural network using the `plot_history()`
# function.
#
# **Expected Results**: The training and validation loss should show that the model is learning the data, but the model is not yet overfitting.
# You will probably see the training accuracy for the model top out below 90%, and validation accuracy will usually be a about the same with more noise.
# Since the validation loos usually never stops decreasing, it appears this model is not yet able to overfit its data.
# A more powerful model that begins to overfit the data should be possible and able to achieve even better accuracy.

# %%
# plot the learning curves history of your neural network model training here

# %% [markdown]
# **Task**: Visualize the decision boundary again for the neural network model using the same
# `plot_decision_regions()` function again.
#
# **Expected Results**: You should see that the neural network with a hidden layer can now carve
# the decision space up into a couple of regions, and the regions boundaries are not
# necessarily lines (e.g. it will curve around a bit for the defined regions).

# %%
# plot the decision boundary learned by your neural network model here

# %% [markdown]
# # Task 3: We Need More Power Scotty!
#
# The previous model with a single intermediate layer appears to not have enough representational
# power for this dataset.
#
# **Task**:  Write a function that creates a `keras.Model` called `get_more_powerful_model()`.
# The tests for this function only test that you have more than 2 intermediate layers.
# Try 4 or 5 intermediate layers with 32 to 64 units in each.  The unittests for this function
# only require that you have more than 2 layers in your function for this task.

# %%
### TESTED FUNCTION get_more_powerful_model()
run_unittests(['test_get_more_powerful_model'])

deep_model = get_more_powerful_model()

# %% [markdown]
# **Task**: For more practice, give the summary and show the architecture of your more
# powerful model in the next cell(s).
#
# **Expected Result**: This is just to double check that the model you will use to train
# with has the number of layers and units in the layers that you think it has.

# %%
# show the summary of your more powerful network model architecture here

# %%
# plot a visualization of your more powerful network model here

# %% [markdown]
# **Task**: Next train your model using the `fit()` function on the `X` inputs
# and `Y` labels.  Use the same settings as before for this training
# (500+ epochs, batch size 32, 20% of the data reserved for validation).
#
# **Expected Result**:
#
# In my testing, the model will overfit but usually you will need more than
# 100 epochs to really see that it is obviously overfitting.  There are
# a lot of almost identical points that have different categories in the data
# so it takes a bit of power and time to get a model to start memorizing.
#
# However, you should find that with somewhere around the number of layers suggested, and 32-128 or so
# units in yur layers, that the model will begin overfitting after 150 to 200 epochs or so.
# You should see validation loss begin to degrade slowly, then quite rapidly at some point
# if you have an overfitting model.  Likewise you will probably observe that validation accuracy
# slowly degrades, though the signal here will be a bit noisy (there are very few data
# points we have for validation here, which increases the variability of our metrics).

# %%
# train your more powerful network model here

# %% [markdown]
# **Task**: Plot the loss and accuracy learning curves again for the more powerful model you created using the `plot_history()`
# function.
#
# **Expected Results**: As mentioned it takes some time for this model to begin clearly overfitting.  But  you should expect that if
# you have around the number of units and layers mentioned, that validation loss will stop improving at some point, and
# will slowly at first and then more rapidly begin increasing.  And that if you train for more epochs than we have been using previously,
# the model will clearly begin overfitting.  Also when overfitting is occurring, the training loss will keep being reduced towards
# 0, though its rate of decrease will slow down, but never truly stop.
#
# For accuracy, when the model is overfitting, you should see the training accuracy rapidly reach a level about 95% then it
# will keep slowly creping up as loss is slowly being reduced.  At the epoch where overfitting begins to occur
# more rapidly, validation accuracy will begin slowly creping down (though again the signal will be kind of noisy and
# maybe a bit hard to see, limiting the y axis might help to better see the downward trend on validation accuracy).

# %%
# plot the learning curve history of your more powerful model's training here

# %% [markdown]
# **Task**: Visualize the decision boundary again as usual for the more powerful model using the
# `plot_decision_regions()` function.
#
# **Expected Results**: Usually I get decision boundaries that look, surprisingly, a bit more regular than
# for the less powerful neural network (like slices of pie).  But more accurate, and often a bit of
# an attempt to carve out some of the most troublesome points at the origin 0,0.

# %%
# visualize the decision boundary learned by your more powerful network model here

# %% [markdown]
# Congratulations on completing assignment 03.  This was a bit shorter than the previous ones.  Hopefully you remembered to
# make commits after each of the 3 tasks and have pushed them to your GitHub repository for grading.  The autograder will
# only be giving 60/60 points for the 3 tasks, I will look that you have completed the ask for plots and visualizations for each
# of the three models in your submitted notebook, and that they look like what we were expecting for the expected
# models.
#
# <font color='blue'>
#
# **What to remember from this assignment:**
#
# 1. Representational power is a function of the number of trainable
#    parameters of a model.
# 2. A simple logistic regression model performs a linear discrimination, it
#    is only capable of creating a linear decision boundary in the decision
#    space to separate the categories it is trying to predict.
# 3. Binary classification network models are a sequence of `Dense` layers
#    that use a nonlinear activation function like `relu` as the output
#    of the layers.
# 4. Binary classification models should have final `Dense` layer with
#    a single unit that uses `sigmoid` activation, to output a prediction
#    in the range 0-1
# 5. Binary classification models should usually use `binary_crossentropy`
#    for their loss function, and the default `rmsprop` optimizer is usually
#    fine for these types of problems.
# 6. A model that is incapable of solving a problem will usually show
#    no ability to be trained to get performance better than a baseline
#    random guessing metric.
# 8. A model without enough representational power will have validation loss
#    curves that keep getting smaller, there will be no sign that validation
#    loss starts getting worse if the model is underpowered.

# %% [markdown]
# # Additional Tasks (Optional)
#
# These are optional things to do, but since you currently have this assignment in mind, here are some suggestions for a few additional things you might
# try or questions that may have been raised from doing this assignment.
#
# ## 1) The power of nonlinear output activation
#
# If you are still not convinced that nonlinear output activation from layers is needed to create a more powerful affine transformation,
# try your most powerful neural network model on this data, but remove all of the intermediate `relu` activation outputs from all
# of your intermediate layers.  Look at the effect this has on the model performance, and especially plot the resulting decision
# boundary.  Can you predict in advance what will happen if you don't have any nonlinear activations in your network?

# %% [markdown]
# ## 2) Practice early stopping
#
# We will be looking at improving generalization in the next assignment.  However you might want to see what kind of performance you can get by maybe
# decreasing the representational power of your model a bit, so that it doesn't overfit so aggressively, and then train it until the
# point where overfitting starts to occur.  What kind of performance do you get on a model that you early stop on when you retrain it on all of the data?

# %% [markdown]
# ## 3) Practice with callbacks
#
# Training for 500 or more epochs may take a bit of time.  Also if you are using the default `verbose=1` parameter for the `fit()` output,
# each epoch will be reported, which will make your notebooks grow long.
#
# You might want to set `verbose=0` to not monitor the output during training.  Additionally, you could practice using the TensorBoard
# callback and the TensorBoard server to monitor your runs while they happen.  Also, while there is no setting to ask Keras to for example
# show output results every 10 or 100 epochs during the `fit()`, it is easy to subclass `Callback` and create one that will report
# loss and accuracy every N epochs (google this, there are many examples of this callback).
